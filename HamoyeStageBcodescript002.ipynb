# %% [markdown]
# # HAMOYE STAGE B

# %%
#import necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import datetime
import scipy as sp
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %% [markdown]
# #### QUESTION NUMBER 2

# %%
#import the csv file

energydf = pd.read_csv(r'file:///C:\Users\USER\Desktop\energydata_complete.csv')
energydf.head()
# Out:
#              date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  11-01-16 17:00          60      30  19.89  47.596667  19.2  44.790000
# 1  11-01-16 17:10          60      30  19.89  46.693333  19.2  44.722500
# 2  11-01-16 17:20          50      30  19.89  46.300000  19.2  44.626667
# 3  11-01-16 17:30          50      40  19.89  46.066667  19.2  44.590000
# 4  11-01-16 17:40          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9  T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53   6.60        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56   6.48        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50   6.37        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40   6.25        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40   6.13        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# ...

# %% [markdown]
# #### QUESTION NUMBER 12

# %%
#calculate the linear regression of T2 and T6

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

X = energydf[["T2"]]
y = energydf["T6"]

linear_model = LinearRegression()
linear_model.fit(X, y)

predictions = linear_model.predict(X)
round(r2_score(y, predictions), 2)
# Out:
# 0.64

# %%
x1 = energydf[["T2"]]
y = energydf["T6"]

x = sm.add_constant(x1)
results = sm.OLS(y, x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     T6   R-squared:                       0.642
# Model:                            OLS   Adj. R-squared:                  0.642
# Method:                 Least Squares   F-statistic:                 3.537e+04
# Date:                Fri, 11 Feb 2022   Prob (F-statistic):               0.00
# Time:                        22:43:03   Log-Likelihood:                -53524.
# No. Observations:               19735   AIC:                         1.071e+05
# Df Residuals:                   19733   BIC:                         1.071e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -37.3495      0.242   -154.306      0.000     -37.824     -36.875
# ...

# %% [markdown]
# #### QUESTION NUMBER 13 TO 17

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

X = energydf[energydf.columns.difference(["date", "lights", "Appliances"])]
y = energydf["Appliances"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

multiple_linear_model = LinearRegression()
multiple_linear_model.fit(X_train, y_train)

test_predictions = multiple_linear_model.predict(X_test)

# %%
x2 =  energydf[energydf.columns.difference(["date", "lights", "Appliances"])]
y = energydf["Appliances"]

x = sm.add_constant(x2)
results = sm.OLS(y, x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Appliances   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     135.3
# Date:                Fri, 11 Feb 2022   Prob (F-statistic):               0.00
# Time:                        22:51:16   Log-Likelihood:            -1.1781e+05
# No. Observations:               19735   AIC:                         2.357e+05
# Df Residuals:                   19709   BIC:                         2.359e+05
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          35.4174     95.623      0.370      0.711    -152.013     222.847
# ...

# %% [markdown]
# #### QUESTION 13(specifically)

# %%
#Calculating the Mean Absolute Error

round(mean_absolute_error(y_test, test_predictions), 2)
# Out:
# 53.64

# %% [markdown]
# #### QUESTION 14(specifically)

# %%
#Residual Sum of Squares to measure the level of variance in the error term

round(np.sum(np.square(y_test - test_predictions)) , 2)
# Out:
# 51916730.72

# %% [markdown]
# #### QUESTION 15(specifically)

# %%
#Calculating the Root Mean Squared Error

round(mean_squared_error(y_test, test_predictions, squared=False), 3)
# Out:
# 93.639

# %% [markdown]
# #### QUESTION 16(specifically)

# %%
#Rsquared to evaluate the performance and accuracy of the linear regression model

round(r2_score(y_test, test_predictions), 2)
# Out:
# 0.15

# %% [markdown]
# #### QUESTION 17(specifically)

# %%
tmptdf = pd.DataFrame([X.columns, multiple_linear_model.coef_]).T
tmptdf.columns = ["attributes", "size"]
tmptdf.sort_values(by="size", ascending=False)
# Out:
#      attributes                   size
# 25          rv2   242084722641512.1875
# 1          RH_1             495.285783
# 13           T3             310.735255
# 16           T6             252.940482
# 21    Tdewpoint             125.369982
# 18           T8             109.162692
# 3          RH_3             102.777179
# 6          RH_6               40.70622
# 23    Windspeed              31.250948
# 14           T4              30.996856
# 4          RH_4              27.386484
# 5          RH_5              16.935852
# 22   Visibility              13.147649
# 17           T7              10.918569
# 0   Press_mm_hg               7.307472
# 11           T1              -3.269625
# 15           T5             -16.693186
# 9          RH_9             -42.681428
# 7          RH_7              -47.48181
# 10       RH_out              -83.06098
# 8          RH_8            -168.560311
# 19           T9            -203.227192
# 12           T2            -252.790493
# ...

# %% [markdown]
# #### QUESTION 18

# %%
from sklearn.linear_model import Ridge

ridge_model = Ridge(alpha=0.4)
ridge_model.fit(X_train, y_train)

test_predictions = ridge_model.predict(X_test)

#Root Mean Squared Error
round(mean_squared_error(y_test, test_predictions, squared=False), 3)
# Out:
# 93.661

# %% [markdown]
# #### QUESTION 19

# %%
from sklearn.linear_model import Lasso

lasso_model = Lasso(alpha=0.001)
lasso_model.fit(X_train, y_train)

test_predictions = lasso_model.predict(X_test)

tmptdf = pd.DataFrame([X.columns, lasso_model.coef_]).T
tmptdf.columns = ["attributes", "size"]
tmptdf.sort_values(by="size", ascending=False)
# Out:
#      attributes        size
# 1          RH_1  494.303958
# 13           T3  310.158452
# 16           T6  249.842145
# 21    Tdewpoint  118.157961
# 18           T8   108.87985
# 3          RH_3  102.220334
# 6          RH_6   40.060784
# 23    Windspeed   31.383255
# 14           T4   30.319703
# 4          RH_4   26.545964
# 5          RH_5   17.016808
# 22   Visibility   13.077305
# 17           T7   10.336382
# 0   Press_mm_hg    7.273476
# 24          rv1    1.620787
# 25          rv2         0.0
# 11           T1   -4.015052
# 15           T5  -17.100949
# 9          RH_9  -42.453636
# 7          RH_7  -47.215438
# 10       RH_out  -78.057598
# 8          RH_8 -168.688577
# 19           T9 -202.520112
# 12           T2 -249.660388
# 20        T_out -332.663335
# 2          RH_2 -465.788906

# %% [markdown]
# #### QUESTION 20

# %%
#Root Mean Squared Error

round(mean_squared_error(y_test, test_predictions, squared=False), 3)
# Out:
# 93.642

# %% [markdown]
# #### Thank You
